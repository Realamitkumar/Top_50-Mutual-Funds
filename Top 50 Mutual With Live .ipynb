# %% [markdown]
# # TOP 50 MUTUAL FUNDS

# %%
#Importing pandas library for data importation
import pandas as pd

# %%
#reading the csv
data=pd.read_csv('Mutuals.csv')

# %% [markdown]
# # Removing unnecessary columns below:

# %%
data.drop(columns=['Unnamed: 1','Unnamed: 2','Unnamed: 4','Unnamed: 5','1 yr Return(%)'],inplace=True)

# %%
data.head(10)
# Out:
#                                   Mutuals      1Y          2Y         3Y  \
# 0  Canara Robeco Flexi Cap Fund - D - (G)   0.030  -13813.60%  -7439.60%
# 1  Canara Robeco Flexi Cap Fund - R - (G)   0.048       4.90%      4.00%
# 2            JM Flexi Cap Fund - DP - (G)   0.042       4.00%      4.80%
# 3            JM Flexi Cap Fund - RP - (G)  -0.010       2.60%      4.40%
# 4              Axis Bluechip Fund - D (G)   0.038       3.60%      4.60%
# 5                  Axis Bluechip Fund (G)   0.095       5.80%      5.00%
# 6         CR Bluechip Equity Fund - D (G)   0.056       5.50%      5.80%
# 7             CR Bluechip Equity Fund (G)   0.046       4.80%      5.50%
# 8      Axis Long Term Equity - Direct (G)   0.036       4.70%      5.80%
# 9          Axis Long Term Equity Fund (G)   0.048       5.40%      3.80%
#
#       4Y     5Y     6Y     7Y     8Y     9Y    10Y
# 0  2.90%  3.80%  3.60%  4.60%  5.50%  5.60%  5.50%
# 1  5.30%  9.50%  5.80%  5.00%  5.60%  5.70%  5.50%
# ...

# %%
# Overall_Mean
_1_yr_Avg=data['1Y'].mean
_2_yr_Avg=data['2Y'].mean
_3_yr_Avg=data['3Y'].mean
_4_yr_Avg=data['4Y'].mean
_5_yr_Avg=data['5Y'].mean
_6_yr_Avg=data['6Y'].mean
_7_yr_Avg=data['7Y'].mean
_8_yr_Avg=data['8Y'].mean
_9_yr_Avg=data['9Y'].mean
_10_yr_Avg=data['10Y'].mean

# %% [markdown]
# # Appending New Columns Into Existing Data

# %%
data['_1_yr_Avg']=data['1Y']
data['_2_yr_Avg']=data['2Y']
data['_3_yr_Avg']=data['3Y']
data['_4_yr_Avg']=data['4Y']
data['_5_yr_Avg']=data['5Y']
data['_6_yr_Avg']=data['6Y']
data['_7_yr_Avg']=data['7Y']
data['_8_yr_Avg']=data['8Y']
data['_9_yr_Avg']=data['9Y']
data['_10_yr_Avg']=data['10Y']

# %%
data.head(5)
# Out:
#                                   Mutuals      1Y          2Y         3Y  \
# 0  Canara Robeco Flexi Cap Fund - D - (G)   0.030  -13813.60%  -7439.60%
# 1  Canara Robeco Flexi Cap Fund - R - (G)   0.048       4.90%      4.00%
# 2            JM Flexi Cap Fund - DP - (G)   0.042       4.00%      4.80%
# 3            JM Flexi Cap Fund - RP - (G)  -0.010       2.60%      4.40%
# 4              Axis Bluechip Fund - D (G)   0.038       3.60%      4.60%
#
#       4Y     5Y     6Y     7Y     8Y     9Y  ... _1_yr_Avg   _2_yr_Avg  \
# 0  2.90%  3.80%  3.60%  4.60%  5.50%  5.60%  ...     0.030  -13813.60%
# 1  5.30%  9.50%  5.80%  5.00%  5.60%  5.70%  ...     0.048       4.90%
# 2  5.40%  5.60%  5.50%  5.80%  5.70%  6.20%  ...     0.042       4.00%
# 3  5.50%  4.60%  4.80%  5.50%  6.20%  6.20%  ...    -0.010       2.60%
# 4  5.50%  3.60%  4.70%  5.80%  6.20%  3.60%  ...     0.038       3.60%
#
#    _3_yr_Avg _4_yr_Avg _5_yr_Avg _6_yr_Avg _7_yr_Avg _8_yr_Avg _9_yr_Avg  \
# ...

# %% [markdown]
# # Standard Deviation:

# %%
std_1Y=data['1Y'].std
std_2Y=data['2Y'].std
std_3Y=data['3Y'].std
std_4Y=data['4Y'].std
std_5Y=data['5Y'].std
std_6Y=data['6Y'].std
std_7Y=data['7Y'].std
std_8Y=data['8Y'].std
std_9Y=data['9Y'].std
std_10Y=data['10Y'].std
std_4Y
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 0      2.90%
# 1      5.30%
# 2      5.40%
# 3      5.50%
# 4      5.50%
# 5      5.60%
# 6      5.70%
# 7      6.20%
# 8      6.20%
# 9      3.60%
# 10     5.80%
# 11     5.50%
# 12     4.80%
# 13     4.80%
# 14     3.60%
# 15     5.90%
# 16     4.60%
# 17    23.50%
# 18    30.10%
# 19    11.70%
# 20    15.70%
# 21    13.90%
# 22     5.50%
# 23     6.89%
# 24    13.50%
# 25    16.10%
# 26     5.70%
# 27    19.90%
# 28    20.30%
# 29    19.80%
# 30    12.80%
# 31       14%
# 32    11.70%
# 33     6.30%
# 34     5.60%
# 35     6.60%
# 36     6.50%
# 37     5.50%
# 38     7.10%
# 39     7.00%
# 40     5.30%
# 41     5.50%
# 42     5.50%
# 43     6.50%
# 44     3.60%
# 45     5.90%
# 46     2.30%
# 47     2.80%
# 48     4.80%
# 49       NaN
# Name: 4Y, dtype: object>

# %% [markdown]
# # Some Best Mutual Funds List

# %%
import requests
from bs4 import BeautifulSoup

# %%
webpage=requests.get('https://www.moneycontrol.com/mutual-funds/best-funds/index.html').text
soup=BeautifulSoup(webpage,'lxml')

# %%
soup.find_all('h1')[0].text
# Out:
# 'Top Ranked Funds'

# %%
for i in soup.find_all('a',class_='robo_medium'):
    print(i.text.strip())
# Out:
# DSP Natural Resources and New Energy Fund - Direct Plan - GrowthSectoral/Thematic
# DSP Natural Resources and New Energy Fund - Regular Plan - GrowthSectoral/Thematic
# Union Largecap Fund - GrowthLarge Cap Fund
# Quant Large and Mid Cap Fund - Direct Plan - GrowthLarge & Mid Cap Fund
# Quant Large and Mid Cap Fund - GrowthLarge & Mid Cap Fund
# IDBI India Top 100 Equity Fund - Direct Plan - GrowthLarge Cap Fund
# IDBI India Top 100 Equity Fund - GrowthLarge Cap Fund
# SBI Focused Equity Fund - Direct Plan - GrowthFocused Fund
# SBI Focused Equity Fund - Regular Plan - GrowthFocused Fund
# Quant Tax Plan - Direct Plan - GrowthELSS
# Invesco India Largecap Fund - Direct Plan - GrowthLarge Cap Fund
# Quant Tax Plan - GrowthELSS
# UTI Mastershare Unit Scheme - Direct Plan - GrowthLarge Cap Fund
# UTI Mastershare Unit Scheme - GrowthLarge Cap Fund
# Canara Robeco Emerging Equities - Direct Plan - GrowthLarge & Mid Cap Fund
# ...

# %% [markdown]
# # I Have Done With My Project

# %% [markdown]
# # I hope you will like this
